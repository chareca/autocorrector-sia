# %% [markdown]
# ## Distancias físicas entre letras

# %%
import numpy as np

def position_matrix():
    filas = ["qwertyuiop", "asdfghjklñ", "zxcvbnm"]

    dic = {}
    for i, fila in enumerate(filas):
        for j, letter in enumerate(fila):
            dic[letter] = [i,j]
    
    return dic

dic = position_matrix()

def euclidean(pos1: np.ndarray, pos2: np.ndarray):
    pos1 = np.array(pos1)
    pos2 = np.array(pos2)
    return np.sqrt(np.sum((pos1-pos2)**2))

def order_ascii(letter1, letter2):
    return "".join(sorted(letter1+letter2))

def create_distances(matrix):
    distances = {}
    keys = list(matrix.keys())
    values = list(matrix.values())
    for i in range(len(keys)):
        for j in range(i+1, len(keys)):
            string = order_ascii(keys[i], keys[j])
            distances[string] = euclidean(values[i], values[j])
    
    return distances

distancias = create_distances(dic)
# Out:
# {'qw': 1.0,
#  'eq': 2.0,
#  'qr': 3.0,
#  'qt': 4.0,
#  'qy': 5.0,
#  'qu': 6.0,
#  'iq': 7.0,
#  'oq': 8.0,
#  'pq': 9.0,
#  'aq': 1.0,
#  'qs': 1.4142135623730951,
#  'dq': 2.23606797749979,
#  'fq': 3.1622776601683795,
#  'gq': 4.123105625617661,
#  'hq': 5.0990195135927845,
#  'jq': 6.082762530298219,
#  'kq': 7.0710678118654755,
#  'lq': 8.06225774829855,
#  'qñ': 9.055385138137417,
#  'qz': 2.0,
#  'qx': 2.23606797749979,
#  'cq': 2.8284271247461903,
#  'qv': 3.605551275463989,
#  'bq': 4.47213595499958,
#  'nq': 5.385164807134504,
#  'mq': 6.324555320336759,
#  'ew': 1.0,
#  'rw': 2.0,
#  'tw': 3.0,
#  'wy': 4.0,
#  'uw': 5.0,
#  'iw': 6.0,
#  'ow': 7.0,
#  'pw': 8.0,
#  'aw': 1.4142135623730951,
#  'sw': 1.0,
#  'dw': 1.4142135623730951,
#  'fw': 2.23606797749979,
#  'gw': 3.1622776601683795,
#  'hw': 4.123105625617661,
#  'jw': 5.0990195135927845,
#  'kw': 6.082762530298219,
#  'lw': 7.0710678118654755,
#  'wñ': 8.06225774829855,
#  'wz': 2.23606797749979,
#  'wx': 2.0,
#  'cw': 2.23606797749979,
#  'vw': 2.8284271247461903,
#  'bw': 3.605551275463989,
#  'nw': 4.47213595499958,
#  'mw': 5.385164807134504,
#  'er': 1.0,
#  'et': 2.0,
#  'ey': 3.0,
#  'eu': 4.0,
#  'ei': 5.0,
#  'eo': 6.0,
#  'ep': 7.0,
#  'ae': 2.23606797749979,
#  'es': 1.4142135623730951,
#  'de': 1.0,
#  'ef': 1.4142135623730951,
#  'eg': 2.23606797749979,
#  'eh': 3.1622776601683795,
#  'ej': 4.123105625617661,
#  'ek': 5.0990195135927845,
#  'el': 6.082762530298219,
#  'eñ': 7.0710678118654755,
#  'ez': 2.8284271247461903,
#  'ex': 2.23606797749979,
#  'ce': 2.0,
#  'ev': 2.23606797749979,
#  'be': 2.8284271247461903,
#  'en': 3.605551275463989,
#  'em': 4.47213595499958,
#  'rt': 1.0,
#  'ry': 2.0,
#  'ru': 3.0,
#  'ir': 4.0,
#  'or': 5.0,
#  'pr': 6.0,
#  'ar': 3.1622776601683795,
#  'rs': 2.23606797749979,
#  'dr': 1.4142135623730951,
#  'fr': 1.0,
#  'gr': 1.4142135623730951,
#  'hr': 2.23606797749979,
#  'jr': 3.1622776601683795,
#  'kr': 4.123105625617661,
#  'lr': 5.0990195135927845,
#  'rñ': 6.082762530298219,
#  'rz': 3.605551275463989,
#  'rx': 2.8284271247461903,
#  'cr': 2.23606797749979,
#  'rv': 2.0,
#  'br': 2.23606797749979,
#  'nr': 2.8284271247461903,
#  'mr': 3.605551275463989,
#  'ty': 1.0,
#  'tu': 2.0,
#  'it': 3.0,
#  'ot': 4.0,
#  'pt': 5.0,
#  'at': 4.123105625617661,
#  'st': 3.1622776601683795,
#  'dt': 2.23606797749979,
#  'ft': 1.4142135623730951,
#  'gt': 1.0,
#  'ht': 1.4142135623730951,
#  'jt': 2.23606797749979,
#  'kt': 3.1622776601683795,
#  'lt': 4.123105625617661,
#  'tñ': 5.0990195135927845,
#  'tz': 4.47213595499958,
#  'tx': 3.605551275463989,
#  'ct': 2.8284271247461903,
#  'tv': 2.23606797749979,
#  'bt': 2.0,
#  'nt': 2.23606797749979,
#  'mt': 2.8284271247461903,
#  'uy': 1.0,
#  'iy': 2.0,
#  'oy': 3.0,
#  'py': 4.0,
#  'ay': 5.0990195135927845,
#  'sy': 4.123105625617661,
#  'dy': 3.1622776601683795,
#  'fy': 2.23606797749979,
#  'gy': 1.4142135623730951,
#  'hy': 1.0,
#  'jy': 1.4142135623730951,
#  'ky': 2.23606797749979,
#  'ly': 3.1622776601683795,
#  'yñ': 4.123105625617661,
#  'yz': 5.385164807134504,
#  'xy': 4.47213595499958,
#  'cy': 3.605551275463989,
#  'vy': 2.8284271247461903,
#  'by': 2.23606797749979,
#  'ny': 2.0,
#  'my': 2.23606797749979,
#  'iu': 1.0,
#  'ou': 2.0,
#  'pu': 3.0,
#  'au': 6.082762530298219,
#  'su': 5.0990195135927845,
#  'du': 4.123105625617661,
#  'fu': 3.1622776601683795,
#  'gu': 2.23606797749979,
#  'hu': 1.4142135623730951,
#  'ju': 1.0,
#  'ku': 1.4142135623730951,
#  'lu': 2.23606797749979,
#  'uñ': 3.1622776601683795,
#  'uz': 6.324555320336759,
#  'ux': 5.385164807134504,
#  'cu': 4.47213595499958,
#  'uv': 3.605551275463989,
#  'bu': 2.8284271247461903,
#  'nu': 2.23606797749979,
#  'mu': 2.0,
#  'io': 1.0,
#  'ip': 2.0,
#  'ai': 7.0710678118654755,
#  'is': 6.082762530298219,
#  'di': 5.0990195135927845,
#  'fi': 4.123105625617661,
#  'gi': 3.1622776601683795,
#  'hi': 2.23606797749979,
#  'ij': 1.4142135623730951,
#  'ik': 1.0,
#  'il': 1.4142135623730951,
#  'iñ': 2.23606797749979,
#  'iz': 7.280109889280518,
#  'ix': 6.324555320336759,
#  'ci': 5.385164807134504,
#  'iv': 4.47213595499958,
#  'bi': 3.605551275463989,
#  'in': 2.8284271247461903,
#  'im': 2.23606797749979,
#  'op': 1.0,
#  'ao': 8.06225774829855,
#  'os': 7.0710678118654755,
#  'do': 6.082762530298219,
#  'fo': 5.0990195135927845,
#  'go': 4.123105625617661,
#  'ho': 3.1622776601683795,
#  'jo': 2.23606797749979,
#  'ko': 1.4142135623730951,
#  'lo': 1.0,
#  'oñ': 1.4142135623730951,
#  'oz': 8.246211251235321,
#  'ox': 7.280109889280518,
#  'co': 6.324555320336759,
#  'ov': 5.385164807134504,
#  'bo': 4.47213595499958,
#  'no': 3.605551275463989,
#  'mo': 2.8284271247461903,
#  'ap': 9.055385138137417,
#  'ps': 8.06225774829855,
#  'dp': 7.0710678118654755,
#  'fp': 6.082762530298219,
#  'gp': 5.0990195135927845,
#  'hp': 4.123105625617661,
#  'jp': 3.1622776601683795,
#  'kp': 2.23606797749979,
#  'lp': 1.4142135623730951,
#  'pñ': 1.0,
#  'pz': 9.219544457292887,
#  'px': 8.246211251235321,
#  'cp': 7.280109889280518,
#  'pv': 6.324555320336759,
#  'bp': 5.385164807134504,
#  'np': 4.47213595499958,
#  'mp': 3.605551275463989,
#  'as': 1.0,
#  'ad': 2.0,
#  'af': 3.0,
#  'ag': 4.0,
#  'ah': 5.0,
#  'aj': 6.0,
#  'ak': 7.0,
#  'al': 8.0,
#  'añ': 9.0,
#  'az': 1.0,
#  'ax': 1.4142135623730951,
#  'ac': 2.23606797749979,
#  'av': 3.1622776601683795,
#  'ab': 4.123105625617661,
#  'an': 5.0990195135927845,
#  'am': 6.082762530298219,
#  'ds': 1.0,
#  'fs': 2.0,
#  'gs': 3.0,
#  'hs': 4.0,
#  'js': 5.0,
#  'ks': 6.0,
#  'ls': 7.0,
#  'sñ': 8.0,
#  'sz': 1.4142135623730951,
#  'sx': 1.0,
#  'cs': 1.4142135623730951,
#  'sv': 2.23606797749979,
#  'bs': 3.1622776601683795,
#  'ns': 4.123105625617661,
#  'ms': 5.0990195135927845,
#  'df': 1.0,
#  'dg': 2.0,
#  'dh': 3.0,
#  'dj': 4.0,
#  'dk': 5.0,
#  'dl': 6.0,
#  'dñ': 7.0,
#  'dz': 2.23606797749979,
#  'dx': 1.4142135623730951,
#  'cd': 1.0,
#  'dv': 1.4142135623730951,
#  'bd': 2.23606797749979,
#  'dn': 3.1622776601683795,
#  'dm': 4.123105625617661,
#  'fg': 1.0,
#  'fh': 2.0,
#  'fj': 3.0,
#  'fk': 4.0,
#  'fl': 5.0,
#  'fñ': 6.0,
#  'fz': 3.1622776601683795,
#  'fx': 2.23606797749979,
#  'cf': 1.4142135623730951,
#  'fv': 1.0,
#  'bf': 1.4142135623730951,
#  'fn': 2.23606797749979,
#  'fm': 3.1622776601683795,
#  'gh': 1.0,
#  'gj': 2.0,
#  'gk': 3.0,
#  'gl': 4.0,
#  'gñ': 5.0,
#  'gz': 4.123105625617661,
#  'gx': 3.1622776601683795,
#  'cg': 2.23606797749979,
#  'gv': 1.4142135623730951,
#  'bg': 1.0,
#  'gn': 1.4142135623730951,
#  'gm': 2.23606797749979,
#  'hj': 1.0,
#  'hk': 2.0,
#  'hl': 3.0,
#  'hñ': 4.0,
#  'hz': 5.0990195135927845,
#  'hx': 4.123105625617661,
#  'ch': 3.1622776601683795,
#  'hv': 2.23606797749979,
#  'bh': 1.4142135623730951,
#  'hn': 1.0,
#  'hm': 1.4142135623730951,
#  'jk': 1.0,
#  'jl': 2.0,
#  'jñ': 3.0,
#  'jz': 6.082762530298219,
#  'jx': 5.0990195135927845,
#  'cj': 4.123105625617661,
#  'jv': 3.1622776601683795,
#  'bj': 2.23606797749979,
#  'jn': 1.4142135623730951,
#  'jm': 1.0,
#  'kl': 1.0,
#  'kñ': 2.0,
#  'kz': 7.0710678118654755,
#  'kx': 6.082762530298219,
#  'ck': 5.0990195135927845,
#  'kv': 4.123105625617661,
#  'bk': 3.1622776601683795,
#  'kn': 2.23606797749979,
#  'km': 1.4142135623730951,
#  'lñ': 1.0,
#  'lz': 8.06225774829855,
#  'lx': 7.0710678118654755,
#  'cl': 6.082762530298219,
#  'lv': 5.0990195135927845,
#  'bl': 4.123105625617661,
#  'ln': 3.1622776601683795,
#  'lm': 2.23606797749979,
#  'zñ': 9.055385138137417,
#  'xñ': 8.06225774829855,
#  'cñ': 7.0710678118654755,
#  'vñ': 6.082762530298219,
#  'bñ': 5.0990195135927845,
#  'nñ': 4.123105625617661,
#  'mñ': 3.1622776601683795,
#  'xz': 1.0,
#  'cz': 2.0,
#  'vz': 3.0,
#  'bz': 4.0,
#  'nz': 5.0,
#  'mz': 6.0,
#  'cx': 1.0,
#  'vx': 2.0,
#  'bx': 3.0,
#  'nx': 4.0,
#  'mx': 5.0,
#  'cv': 1.0,
#  'bc': 2.0,
#  'cn': 3.0,
#  'cm': 4.0,
#  'bv': 1.0,
#  'nv': 2.0,
#  'mv': 3.0,
#  'bn': 1.0,
#  'bm': 2.0,
#  'mn': 1.0}
