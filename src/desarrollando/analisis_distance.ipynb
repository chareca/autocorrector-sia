# %% [markdown]
# **Mejora por cercania fisica en el teclado**
#
#
# El sistema base utiliza la distancia de Levenshtein, que asume que todos los errores humanos son iguales (sustituir 'a' por 's' cuesta lo mismo que 'a' por 'z').
#
# El objetivo de esta mejora es reflejar la realidad del error humano: los usuarios fallan por cercanía física en el teclado.
#
# Al penalizar menos los errores "lógicos", el autocorrector priorizará candidatos que tengan sentido sobre palabras aleatorias que simplemente están a la misma distancia matemática.

# %%
from pathlib import Path
import re
import os

def normalizar_tildes(texto: str) -> str:
    return texto.translate(str.maketrans('áéíóúü', 'aeiouu'))

ruta_libros = Path('../../libros')
files = os.listdir(ruta_libros)
words = {}
for file in files:
    with open(ruta_libros/file, 'r', encoding='UTF-8') as f:
        for linea in f:
            linea = normalizar_tildes(linea.lower())
            linea = re.sub(r'[^\w\s]','', linea)

            for word in linea.split():
                words[word] = words.get(word,0) + 1

# %% [markdown]
# **Funciones para aplicar una edicion**
#
# Aplicamos las 4 funciones base, insertar, borrar, reemplazar e intercambiar:

# %%
def insert(word: str) -> set:
    alphabet = 'abcdefghijklmnñopqrstuvwxyz'
    words_created = set()
    for i in range(len(word) + 1):
        for char in alphabet:
            new_word = word[:i] + char + word[i:]
            words_created.add(new_word)
    
    return words_created

def delete(word: str) -> set:
    words_created = set()
    for i in range(len(word)):
        new_word = word[:i] + word[i+1:]
        words_created.add(new_word)

    return words_created
    
def replace(word: str) -> set:
    alphabet = 'abcdefghijklmnñopqrstuvwxyz'
    words_created = set()
    for i in range(len(word)):
        for char in alphabet:
            new_word = word[:i] + char + word[i+1:]
            words_created.add(new_word)

    return words_created

def exchange(word: str) -> set:
    words_created = set()
    for i in range(len(word) - 1):
        new_word = word[:i] + word[i+1] + word[i] + word[i+2:]
        words_created.add(new_word)

    return words_created

# %% [markdown]
# **Funcion una edicion y dos ediciones**
#
# Debemos recibir una palabra y aplicar las 4 operaciones basicas y devolver las palabras unicas a distancia uno o distancia dos:

# %%
def una_edicion(word:str, intercambiar: bool=False) ->set:
    set1 = insert(word)
    set2 = delete(word)
    set3 = replace(word)
    if not intercambiar:
        return set1.union(set2, set3)
    
    set4 = exchange(word)
    return set1.union(set2, set3, set4)


def dos_ediciones(word:str,intercambiar:bool =False) ->set:
    palabras_ed1 = una_edicion(word, intercambiar)
    palabras_ed2 = set()
    for palabra in palabras_ed1:
        palabras_ed2 = palabras_ed2.union(una_edicion(palabra, intercambiar))
    return palabras_ed2

# %% [markdown]
# **Filtrado de candidatos por vocabulario**
#
# A partir de los candidatos a una y dos ediciones, nos quedamos solo con los que existen en el corpus para evitar sugerencias imposibles.

# %%
def palabras_conocidas(candidatas: set, vocabulario: dict, min_freq: int = 3) -> set:
    return {pal for pal in candidatas if vocabulario.get(pal, 0) >= min_freq}

#De esta forma no tenemos que calcular las dos ediciones habiendo ya calculado palabras a una edicion
def candidatos(word: str, vocabulario: dict, intercambiar: bool = True, min_freq: int = 3) -> set:
    if vocabulario.get(word, 0) >= min_freq:
        return {word}
    c1 = palabras_conocidas(una_edicion(word, intercambiar), vocabulario, min_freq=min_freq)
    if c1:
        return c1
    c2 = palabras_conocidas(dos_ediciones(word, intercambiar), vocabulario, min_freq=min_freq)
    if c2:
        return c2
    return {word}

# %% [markdown]
# **Distancia de teclado + Damerau-Levenshtein ponderada**
#
# Para reemplazos, la penalización depende de qué tan cerca estén las teclas. Sustituir letras vecinas cuesta menos que sustituir letras lejanas.
# Además para incluir una mejora con poco cambio en la arquitectura general, agregamos un hiper parametro como lo es min_freq el cual permite que
# haya un numero minimo de veces que aparezca una palabra para que asi en teoria, sea mas problable la palabra corregida y no caiga en sesgos por el
# conjunto de entrenamiento.

# %%
import numpy as np

def mapa_teclado_es() -> dict:
    filas = ["qwertyuiop", "asdfghjklñ", "zxcvbnm"]
    posiciones = {}
    for i, fila in enumerate(filas):
        for j, letra in enumerate(fila):
            posiciones[letra] = (i, j)
    return posiciones

TECLADO_POS = mapa_teclado_es() #cargamos las posiciones de las letras

def distancia_euclidea_2d(p1: np.ndarray, p2: np.ndarray) -> float:
    pos1 = np.array(p1)
    pos2 = np.array(p2)
    return np.sqrt(np.sum((pos1-pos2)**2))

def costo_reemplazo(letra_origen: str, letra_destino: str, a: float = 2.0) -> float:
    # si no cambia la letra, no hay costo
    if letra_origen == letra_destino:
        return 0.0

    pos_origen = TECLADO_POS.get(letra_origen)
    pos_destino = TECLADO_POS.get(letra_destino)

    # si alguna letra no está en el mapa, usamos costo estándar
    if pos_origen is None or pos_destino is None:
        return 1.0

    # distancia euclídea normalizada para no desbalancear inserción/borrado
    distancia = distancia_euclidea_2d(pos_origen, pos_destino)
    return distancia / a

def distancia_levenshtein_ponderada(origen: str, destino: str, a: float=2.0, costo_intercambio: float = 0.5) -> float:
    filas,columnas = len(origen) + 1, len(destino) + 1

    # matriz = costo mínimo para transformar palabra origen en palabra destino
    matriz = np.zeros(shape=(filas, columnas), dtype=np.float32)

    # caso base: convertir a cadena vacía (borrados) o desde vacía (inserciones)
    matriz[:, 0] = np.arange(filas).ravel()
    matriz[0, :] = np.arange(columnas).ravel()

    for i in range(1, filas):
        for j in range(1, columnas):
            costo_insertar = matriz[i][j - 1] + 1.0
            costo_borrar = matriz[i - 1][j] + 1.0
            costo_reemplazar_actual = matriz[i - 1][j - 1] + costo_reemplazo(origen[i - 1], destino[j - 1], a=a)
            matriz[i][j] = min(costo_insertar, costo_borrar, costo_reemplazar_actual)

            if (i > 1 and j > 1 and origen[i - 1] == destino[j - 2] and origen[i - 2] == destino[j - 1]):
                matriz[i][j] = min(matriz[i][j], matriz[i - 2][j - 2] + costo_intercambio)

    return matriz[filas-1][columnas-1]

# %% [markdown]
# **Ranking final de sugerencias**
#
# Ordenamos por menor distancia y, en empate, por mayor frecuencia en el corpus.

# %%
def sugerencias(word: str, corpus: dict, top_k: int = 10, intercambiar: bool = True, a: float = 4.0, min_freq: int = 3, costo_intercambio: float = 0.5):
    word = normalizar_tildes(word.lower())
    cands = candidatos(word, corpus, intercambiar, min_freq=min_freq)

    ranking = []
    for cand in cands:
        dist = distancia_levenshtein_ponderada(word, cand, a=a, costo_intercambio=costo_intercambio)
        freq = corpus.get(cand, 0)
        ranking.append((cand, dist, freq))

    ranking.sort(key=lambda x: (x[1], -x[2], x[0]))  # (dist, freq desc, palabra)
    return ranking[:top_k]

# %% [markdown]
# **Pruebas con el conjunto de validacion**

# %%
# X_val: 20 frases del corpus para validacion.
# Esta seleccion esta pensada para comparar una configuracion base
# (por ejemplo a=1, min_freq=1) frente a la version mejorada.
X_val = [
    ("en los gobiernos civiles por donde paso el matrimonio no quedaron ni los clavos", "en los gobiernos civiles por donde paso el matrimonio no quedaron ni los clvos"),
    ("no vas ahora a vernos le dijo alguna vez que le encontro en la calle catalina", "no vas ahora a vrnos le dijo alguna vez que le encontro en la calle catalina"),
    ("no creo que habras venido a contarme unas cuantas bolas", "no creo que habras veido a contarme unas cuantas bolas"),
    ("esta ahora con unos amigos en el comedor", "esta ahora con unos aimgos en el comedor"),
    ("aqui no corre tanto el aire dijo un viejo mendigo que se preparaba a tenderse cerca de manuel", "aqui no corre tanto el aire dijo un viejo menigo que se preparaba a tenderse cerca de manuel"),
    ("tome posesion de mi cuchitril y comence mis trabajos", "tome posesion de mi cuchitril y comence mis trabjos"),
    ("ochoa grita ya estan ahi", "ochoa girta ya estan ahi"),
    ("comimos el arroz que estaba excesivamente sabroso", "comimos el ardoz que estaba excesivamente sabroso"),
    ("usted siempre podra llevar una buena vida si quiere replico mingote", "usted siempre opdra llevar una buena vida si quiere replico mingote"),
    ("durante los demas dias de la semana la barraca del domador estuvo vacia", "durante los demas dias de la semana la barraca del domador estuvo avcia"),
    ("la petra y el no se entendian y el matrimonio andaba siempre a trastazos", "la petra y el no se entendian y el matrimonio nadaba siempre a trastazos"),
    ("el chico no podra ir al colegio", "el chico no podar ir al colegio"),
    ("tengo que enviar todos los meses duros a mi familia para que mi madre y mis dos hermanas vayan viviendo", "tengo que enviar todos los meses duros a mi familia para que mi madre y mis dos hermanas vagan viviendo"),
    ("comenzaba a hacer calor pasaban muchos curas por las callejuelas", "comenzaba a hacer calor pasaban muchos cruas por las callejuelas"),
    ("al amanecer del dia mina con la columna en orden de combate entro en el pueblo", "al amanecer del dia mina con la columna en orden de combat entro en el pueblo"),
    ("me ha recordado usted a su excelencia el duque de otranto", "me ha recordado usted a su excelencia el duqe de otranto"),
    ("el toque de oracion el del angelus el de la agonia el de la misa el de los funerales", "el yoque de oracion el del angelus el de la agonia el de la misa el de los funerales"),
    ("pero no crea usted que todos tienen un gran respeto ni por don carlos ni por sus generales", "pero no crea usted que todos tienen un gran respeto ni por don carlos ni por sus generalse"),
    ("riego impaciente mando cinco compañias y ordeno la prision inmediata de los generales", "riego impaciente mando cinco compañias y ordeno la prision inmediata de los generalse"),
    ("el pasado la feria de los discretos", "el pasado la fedia de los discretos"),
]

# %%
def corregir_palabra(word: str, corpus: dict, intercambiar: bool = True, a: float = 4.0, min_freq: int = 3, costo_intercambio: float = 0.5) -> str:
    ranking = sugerencias(word, corpus, top_k=1, intercambiar=intercambiar, a=a, min_freq=min_freq, costo_intercambio=costo_intercambio)
    if not ranking:
        return word
    return ranking[0][0]


def corregir_frase(frase: str, corpus: dict, intercambiar: bool = True, a: float = 4.0, min_freq: int = 3, costo_intercambio: float = 0.5) -> str:
    tokens = normalizar_tildes(frase.lower()).split()
    corregidos = [corregir_palabra(tok, corpus, intercambiar=intercambiar, a=a, min_freq=min_freq, costo_intercambio=costo_intercambio) for tok in tokens]
    return " ".join(corregidos)


def medir_accuracy(X_val: list, corpus: dict, intercambiar: bool = True, a: float = 4.0, min_freq: int = 3, costo_intercambio: float = 0.5, devolver_detalles: bool = True) -> dict:
    total = len(X_val)
    aciertos = 0
    detalles = []

    for frase_correcta, frase_con_error in X_val:
        frase_correcta_norm = normalizar_tildes(frase_correcta.lower())
        pred = corregir_frase(frase_con_error, corpus, intercambiar=intercambiar, a=a, min_freq=min_freq)
        ok = pred == frase_correcta_norm
        aciertos += int(ok)

        if devolver_detalles:
            detalles.append({
                "frase_correcta": frase_correcta_norm,
                "frase_con_error": normalizar_tildes(frase_con_error.lower()),
                "prediccion": pred,
                "acierto": ok,
            })

    resultado = {"accuracy": aciertos / total if total > 0 else 0.0,"aciertos": aciertos,"total": total, }

    if devolver_detalles:
        resultado["detalles"] = detalles

    return resultado


base = medir_accuracy(X_val, words, intercambiar=True, a=1.0, min_freq=1, costo_intercambio=0.5, devolver_detalles=False)
print(f"Base -> {base['accuracy']:.2%} ({base['aciertos']}/{base['total']})")

mejor = None
for a in [1.0, 2.0, 1.5, 3.0, 4.0]:
    for min_freq in [1,2,3,4,5]:
        for costo_intercambio in np.arange(0.1, 2, 0.1):
            r = medir_accuracy(X_val, words, intercambiar=True, a=a, min_freq=min_freq, costo_intercambio=costo_intercambio, devolver_detalles=False)
            print(f"a={a}, min_freq={min_freq}, costo_intercambio={costo_intercambio} -> {r['accuracy']:.2%} ({r['aciertos']}/{r['total']})")
            if mejor is None or r['accuracy'] > mejor['resultado']['accuracy']:
                mejor = {"a": a, "min_freq": min_freq, "resultado": r, "costo_intercambio": costo_intercambio}

print()
print(
    f"Mejor -> a={mejor['a']}, min_freq={mejor['min_freq']}, costo_intercambio={mejor['costo_intercambio']} | "
    f"{mejor['resultado']['accuracy']:.2%} ({mejor['resultado']['aciertos']}/{mejor['resultado']['total']})"
)

res = medir_accuracy(X_val, words, intercambiar=True, a=mejor['a'], min_freq=mejor['min_freq'])
print(f"Seleccionado para detalle -> {res['accuracy']:.2%} ({res['aciertos']}/{res['total']})")
print()
# Out:
# Base -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=0.1 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=0.2 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=0.30000000000000004 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=0.4 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=0.5 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=0.6 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=0.7000000000000001 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=0.8 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=0.9 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.0 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.1 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.2000000000000002 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.3000000000000003 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.4000000000000001 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.5000000000000002 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.6 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.7000000000000002 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.8000000000000003 -> 60.00% (12/20)
# a=1.0, min_freq=1, costo_intercambio=1.9000000000000001 -> 60.00% (12/20)
# a=1.0, min_freq=2, costo_intercambio=0.1 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=0.2 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=0.30000000000000004 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=0.4 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=0.5 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=0.6 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=0.7000000000000001 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=0.8 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=0.9 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.0 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.1 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.2000000000000002 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.3000000000000003 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.4000000000000001 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.5000000000000002 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.6 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.7000000000000002 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.8000000000000003 -> 85.00% (17/20)
# a=1.0, min_freq=2, costo_intercambio=1.9000000000000001 -> 85.00% (17/20)
# a=1.0, min_freq=3, costo_intercambio=0.1 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=0.2 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=0.30000000000000004 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=0.4 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=0.5 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=0.6 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=0.7000000000000001 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=0.8 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=0.9 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.0 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.1 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.2000000000000002 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.3000000000000003 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.4000000000000001 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.5000000000000002 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.6 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.7000000000000002 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.8000000000000003 -> 90.00% (18/20)
# a=1.0, min_freq=3, costo_intercambio=1.9000000000000001 -> 90.00% (18/20)
# a=1.0, min_freq=4, costo_intercambio=0.1 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=0.2 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=0.30000000000000004 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=0.4 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=0.5 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=0.6 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=0.7000000000000001 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=0.8 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=0.9 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.0 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.1 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.2000000000000002 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.3000000000000003 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.4000000000000001 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.5000000000000002 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.6 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.7000000000000002 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.8000000000000003 -> 80.00% (16/20)
# a=1.0, min_freq=4, costo_intercambio=1.9000000000000001 -> 80.00% (16/20)
# a=1.0, min_freq=5, costo_intercambio=0.1 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=0.2 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=0.30000000000000004 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=0.4 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=0.5 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=0.6 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=0.7000000000000001 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=0.8 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=0.9 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.0 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.1 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.2000000000000002 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.3000000000000003 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.4000000000000001 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.5000000000000002 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.6 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.7000000000000002 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.8000000000000003 -> 75.00% (15/20)
# a=1.0, min_freq=5, costo_intercambio=1.9000000000000001 -> 75.00% (15/20)
# a=2.0, min_freq=1, costo_intercambio=0.1 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=0.2 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=0.30000000000000004 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=0.4 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=0.5 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=0.6 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=0.7000000000000001 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=0.8 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=0.9 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.0 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.1 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.2000000000000002 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.3000000000000003 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.4000000000000001 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.5000000000000002 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.6 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.7000000000000002 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.8000000000000003 -> 60.00% (12/20)
# a=2.0, min_freq=1, costo_intercambio=1.9000000000000001 -> 60.00% (12/20)
# a=2.0, min_freq=2, costo_intercambio=0.1 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=0.2 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=0.30000000000000004 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=0.4 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=0.5 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=0.6 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=0.7000000000000001 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=0.8 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=0.9 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.0 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.1 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.2000000000000002 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.3000000000000003 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.4000000000000001 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.5000000000000002 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.6 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.7000000000000002 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.8000000000000003 -> 90.00% (18/20)
# a=2.0, min_freq=2, costo_intercambio=1.9000000000000001 -> 90.00% (18/20)
# a=2.0, min_freq=3, costo_intercambio=0.1 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=0.2 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=0.30000000000000004 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=0.4 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=0.5 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=0.6 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=0.7000000000000001 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=0.8 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=0.9 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.0 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.1 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.2000000000000002 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.3000000000000003 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.4000000000000001 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.5000000000000002 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.6 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.7000000000000002 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.8000000000000003 -> 95.00% (19/20)
# a=2.0, min_freq=3, costo_intercambio=1.9000000000000001 -> 95.00% (19/20)
# a=2.0, min_freq=4, costo_intercambio=0.1 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=0.2 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=0.30000000000000004 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=0.4 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=0.5 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=0.6 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=0.7000000000000001 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=0.8 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=0.9 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.0 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.1 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.2000000000000002 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.3000000000000003 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.4000000000000001 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.5000000000000002 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.6 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.7000000000000002 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.8000000000000003 -> 85.00% (17/20)
# a=2.0, min_freq=4, costo_intercambio=1.9000000000000001 -> 85.00% (17/20)
# a=2.0, min_freq=5, costo_intercambio=0.1 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=0.2 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=0.30000000000000004 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=0.4 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=0.5 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=0.6 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=0.7000000000000001 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=0.8 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=0.9 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.0 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.1 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.2000000000000002 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.3000000000000003 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.4000000000000001 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.5000000000000002 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.6 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.7000000000000002 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.8000000000000003 -> 80.00% (16/20)
# a=2.0, min_freq=5, costo_intercambio=1.9000000000000001 -> 80.00% (16/20)
# a=1.5, min_freq=1, costo_intercambio=0.1 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=0.2 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=0.30000000000000004 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=0.4 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=0.5 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=0.6 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=0.7000000000000001 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=0.8 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=0.9 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.0 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.1 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.2000000000000002 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.3000000000000003 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.4000000000000001 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.5000000000000002 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.6 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.7000000000000002 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.8000000000000003 -> 60.00% (12/20)
# a=1.5, min_freq=1, costo_intercambio=1.9000000000000001 -> 60.00% (12/20)
# a=1.5, min_freq=2, costo_intercambio=0.1 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=0.2 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=0.30000000000000004 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=0.4 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=0.5 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=0.6 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=0.7000000000000001 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=0.8 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=0.9 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.0 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.1 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.2000000000000002 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.3000000000000003 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.4000000000000001 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.5000000000000002 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.6 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.7000000000000002 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.8000000000000003 -> 90.00% (18/20)
# a=1.5, min_freq=2, costo_intercambio=1.9000000000000001 -> 90.00% (18/20)
# a=1.5, min_freq=3, costo_intercambio=0.1 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=0.2 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=0.30000000000000004 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=0.4 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=0.5 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=0.6 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=0.7000000000000001 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=0.8 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=0.9 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.0 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.1 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.2000000000000002 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.3000000000000003 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.4000000000000001 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.5000000000000002 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.6 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.7000000000000002 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.8000000000000003 -> 95.00% (19/20)
# a=1.5, min_freq=3, costo_intercambio=1.9000000000000001 -> 95.00% (19/20)
# a=1.5, min_freq=4, costo_intercambio=0.1 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=0.2 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=0.30000000000000004 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=0.4 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=0.5 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=0.6 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=0.7000000000000001 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=0.8 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=0.9 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.0 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.1 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.2000000000000002 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.3000000000000003 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.4000000000000001 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.5000000000000002 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.6 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.7000000000000002 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.8000000000000003 -> 85.00% (17/20)
# a=1.5, min_freq=4, costo_intercambio=1.9000000000000001 -> 85.00% (17/20)
# a=1.5, min_freq=5, costo_intercambio=0.1 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=0.2 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=0.30000000000000004 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=0.4 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=0.5 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=0.6 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=0.7000000000000001 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=0.8 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=0.9 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.0 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.1 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.2000000000000002 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.3000000000000003 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.4000000000000001 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.5000000000000002 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.6 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.7000000000000002 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.8000000000000003 -> 80.00% (16/20)
# a=1.5, min_freq=5, costo_intercambio=1.9000000000000001 -> 80.00% (16/20)
# a=3.0, min_freq=1, costo_intercambio=0.1 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=0.2 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=0.30000000000000004 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=0.4 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=0.5 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=0.6 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=0.7000000000000001 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=0.8 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=0.9 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.0 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.1 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.2000000000000002 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.3000000000000003 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.4000000000000001 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.5000000000000002 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.6 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.7000000000000002 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.8000000000000003 -> 40.00% (8/20)
# a=3.0, min_freq=1, costo_intercambio=1.9000000000000001 -> 40.00% (8/20)
# a=3.0, min_freq=2, costo_intercambio=0.1 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=0.2 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=0.30000000000000004 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=0.4 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=0.5 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=0.6 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=0.7000000000000001 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=0.8 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=0.9 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.0 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.1 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.2000000000000002 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.3000000000000003 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.4000000000000001 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.5000000000000002 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.6 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.7000000000000002 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.8000000000000003 -> 75.00% (15/20)
# a=3.0, min_freq=2, costo_intercambio=1.9000000000000001 -> 75.00% (15/20)
# a=3.0, min_freq=3, costo_intercambio=0.1 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=0.2 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=0.30000000000000004 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=0.4 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=0.5 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=0.6 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=0.7000000000000001 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=0.8 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=0.9 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.0 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.1 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.2000000000000002 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.3000000000000003 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.4000000000000001 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.5000000000000002 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.6 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.7000000000000002 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.8000000000000003 -> 85.00% (17/20)
# a=3.0, min_freq=3, costo_intercambio=1.9000000000000001 -> 85.00% (17/20)
# a=3.0, min_freq=4, costo_intercambio=0.1 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=0.2 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=0.30000000000000004 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=0.4 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=0.5 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=0.6 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=0.7000000000000001 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=0.8 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=0.9 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.0 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.1 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.2000000000000002 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.3000000000000003 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.4000000000000001 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.5000000000000002 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.6 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.7000000000000002 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.8000000000000003 -> 75.00% (15/20)
# a=3.0, min_freq=4, costo_intercambio=1.9000000000000001 -> 75.00% (15/20)
# a=3.0, min_freq=5, costo_intercambio=0.1 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=0.2 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=0.30000000000000004 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=0.4 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=0.5 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=0.6 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=0.7000000000000001 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=0.8 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=0.9 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.0 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.1 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.2000000000000002 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.3000000000000003 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.4000000000000001 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.5000000000000002 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.6 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.7000000000000002 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.8000000000000003 -> 70.00% (14/20)
# a=3.0, min_freq=5, costo_intercambio=1.9000000000000001 -> 70.00% (14/20)
# a=4.0, min_freq=1, costo_intercambio=0.1 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=0.2 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=0.30000000000000004 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=0.4 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=0.5 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=0.6 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=0.7000000000000001 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=0.8 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=0.9 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.0 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.1 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.2000000000000002 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.3000000000000003 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.4000000000000001 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.5000000000000002 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.6 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.7000000000000002 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.8000000000000003 -> 35.00% (7/20)
# a=4.0, min_freq=1, costo_intercambio=1.9000000000000001 -> 35.00% (7/20)
# a=4.0, min_freq=2, costo_intercambio=0.1 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=0.2 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=0.30000000000000004 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=0.4 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=0.5 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=0.6 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=0.7000000000000001 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=0.8 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=0.9 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.0 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.1 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.2000000000000002 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.3000000000000003 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.4000000000000001 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.5000000000000002 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.6 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.7000000000000002 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.8000000000000003 -> 65.00% (13/20)
# a=4.0, min_freq=2, costo_intercambio=1.9000000000000001 -> 65.00% (13/20)
# a=4.0, min_freq=3, costo_intercambio=0.1 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=0.2 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=0.30000000000000004 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=0.4 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=0.5 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=0.6 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=0.7000000000000001 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=0.8 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=0.9 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.0 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.1 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.2000000000000002 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.3000000000000003 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.4000000000000001 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.5000000000000002 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.6 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.7000000000000002 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.8000000000000003 -> 85.00% (17/20)
# a=4.0, min_freq=3, costo_intercambio=1.9000000000000001 -> 85.00% (17/20)
# a=4.0, min_freq=4, costo_intercambio=0.1 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=0.2 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=0.30000000000000004 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=0.4 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=0.5 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=0.6 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=0.7000000000000001 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=0.8 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=0.9 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.0 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.1 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.2000000000000002 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.3000000000000003 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.4000000000000001 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.5000000000000002 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.6 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.7000000000000002 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.8000000000000003 -> 75.00% (15/20)
# a=4.0, min_freq=4, costo_intercambio=1.9000000000000001 -> 75.00% (15/20)
# a=4.0, min_freq=5, costo_intercambio=0.1 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=0.2 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=0.30000000000000004 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=0.4 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=0.5 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=0.6 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=0.7000000000000001 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=0.8 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=0.9 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.0 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.1 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.2000000000000002 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.3000000000000003 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.4000000000000001 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.5000000000000002 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.6 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.7000000000000002 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.8000000000000003 -> 70.00% (14/20)
# a=4.0, min_freq=5, costo_intercambio=1.9000000000000001 -> 70.00% (14/20)
#
# Mejor -> a=2.0, min_freq=3, costo_intercambio=0.1 | 95.00% (19/20)
# Seleccionado para detalle -> 95.00% (19/20)

# %% [markdown]
# Comprobamos que hay una mejora notoria con el autocorrector base, el cual simulamos poniendo como hiper parametros a=1 y min frecuencia =1.
#
# De todos los hiper parametros para el conjunto de validacion obtenemos que los mejores son con a=2 y y min_freq =3 dandonos un 95% de accuracy por lo que este sera el modelo
# que usemos para el conjunto test.

# %%
res_mejor = medir_accuracy(X_val, words, intercambiar=True, a=mejor['a'], min_freq=mejor['min_freq'], costo_intercambio=mejor['costo_intercambio'])
print(f"Detalle con mejores hiperparametros: a={mejor['a']}, min_freq={mejor['min_freq']}, costo_intercambio={mejor['costo_intercambio']}")
print()

# detalle frase por frase
for i, item in enumerate(res_mejor.get("detalles", []), start=1):
    estado = "OK" if item["acierto"] else "FAIL"
    print(f"[{i:02d}] {estado}")
    print(f"  error:      {item['frase_con_error']}")
    print(f"  prediccion: {item['prediccion']}")
    print(f"  correcta:   {item['frase_correcta']}")
    print()
# Out:
# Detalle con mejores hiperparametros: a=2.0, min_freq=3, costo_intercambio=0.1
#
# [01] OK
#   error:      en los gobiernos civiles por donde paso el matrimonio no quedaron ni los clvos
#   prediccion: en los gobiernos civiles por donde paso el matrimonio no quedaron ni los clavos
#   correcta:   en los gobiernos civiles por donde paso el matrimonio no quedaron ni los clavos
#
# [02] OK
#   error:      no vas ahora a vrnos le dijo alguna vez que le encontro en la calle catalina
#   prediccion: no vas ahora a vernos le dijo alguna vez que le encontro en la calle catalina
#   correcta:   no vas ahora a vernos le dijo alguna vez que le encontro en la calle catalina
#
# [03] OK
#   error:      no creo que habras veido a contarme unas cuantas bolas
#   prediccion: no creo que habras venido a contarme unas cuantas bolas
#   correcta:   no creo que habras venido a contarme unas cuantas bolas
#
# [04] OK
#   error:      esta ahora con unos aimgos en el comedor
#   prediccion: esta ahora con unos amigos en el comedor
#   correcta:   esta ahora con unos amigos en el comedor
#
# [05] OK
#   error:      aqui no corre tanto el aire dijo un viejo menigo que se preparaba a tenderse cerca de manuel
#   prediccion: aqui no corre tanto el aire dijo un viejo mendigo que se preparaba a tenderse cerca de manuel
#   correcta:   aqui no corre tanto el aire dijo un viejo mendigo que se preparaba a tenderse cerca de manuel
#
# [06] OK
#   error:      tome posesion de mi cuchitril y comence mis trabjos
#   prediccion: tome posesion de mi cuchitril y comence mis trabajos
#   correcta:   tome posesion de mi cuchitril y comence mis trabajos
#
# [07] OK
#   error:      ochoa girta ya estan ahi
#   prediccion: ochoa grita ya estan ahi
#   correcta:   ochoa grita ya estan ahi
#
# [08] FAIL
#   error:      comimos el ardoz que estaba excesivamente sabroso
#   prediccion: comimos el arroz que estaba excesivamente astroso
#   correcta:   comimos el arroz que estaba excesivamente sabroso
#
# [09] OK
#   error:      usted siempre opdra llevar una buena vida si quiere replico mingote
#   prediccion: usted siempre podra llevar una buena vida si quiere replico mingote
#   correcta:   usted siempre podra llevar una buena vida si quiere replico mingote
#
# [10] OK
#   error:      durante los demas dias de la semana la barraca del domador estuvo avcia
#   prediccion: durante los demas dias de la semana la barraca del domador estuvo vacia
#   correcta:   durante los demas dias de la semana la barraca del domador estuvo vacia
#
# [11] OK
#   error:      la petra y el no se entendian y el matrimonio nadaba siempre a trastazos
#   prediccion: la petra y el no se entendian y el matrimonio andaba siempre a trastazos
#   correcta:   la petra y el no se entendian y el matrimonio andaba siempre a trastazos
#
# [12] OK
#   error:      el chico no podar ir al colegio
#   prediccion: el chico no podra ir al colegio
#   correcta:   el chico no podra ir al colegio
#
# [13] OK
#   error:      tengo que enviar todos los meses duros a mi familia para que mi madre y mis dos hermanas vagan viviendo
#   prediccion: tengo que enviar todos los meses duros a mi familia para que mi madre y mis dos hermanas vayan viviendo
#   correcta:   tengo que enviar todos los meses duros a mi familia para que mi madre y mis dos hermanas vayan viviendo
#
# [14] OK
#   error:      comenzaba a hacer calor pasaban muchos cruas por las callejuelas
#   prediccion: comenzaba a hacer calor pasaban muchos curas por las callejuelas
#   correcta:   comenzaba a hacer calor pasaban muchos curas por las callejuelas
#
# [15] OK
#   error:      al amanecer del dia mina con la columna en orden de combat entro en el pueblo
#   prediccion: al amanecer del dia mina con la columna en orden de combate entro en el pueblo
#   correcta:   al amanecer del dia mina con la columna en orden de combate entro en el pueblo
#
# [16] OK
#   error:      me ha recordado usted a su excelencia el duqe de otranto
#   prediccion: me ha recordado usted a su excelencia el duque de otranto
#   correcta:   me ha recordado usted a su excelencia el duque de otranto
#
# [17] OK
#   error:      el yoque de oracion el del angelus el de la agonia el de la misa el de los funerales
#   prediccion: el toque de oracion el del angelus el de la agonia el de la misa el de los funerales
#   correcta:   el toque de oracion el del angelus el de la agonia el de la misa el de los funerales
#
# [18] OK
#   error:      pero no crea usted que todos tienen un gran respeto ni por don carlos ni por sus generalse
#   prediccion: pero no crea usted que todos tienen un gran respeto ni por don carlos ni por sus generales
#   correcta:   pero no crea usted que todos tienen un gran respeto ni por don carlos ni por sus generales
#
# [19] OK
#   error:      riego impaciente mando cinco compañias y ordeno la prision inmediata de los generalse
#   prediccion: riego impaciente mando cinco compañias y ordeno la prision inmediata de los generales
#   correcta:   riego impaciente mando cinco compañias y ordeno la prision inmediata de los generales
#
# [20] OK
#   error:      el pasado la fedia de los discretos
#   prediccion: el pasado la feria de los discretos
#   correcta:   el pasado la feria de los discretos

# %% [markdown]
# **Analisis de errores**
#
# error:      comimos el ardoz que estaba excesivamente sabroso
# prediccion: comimos el arroz que estaba excesivamente astroso
# correcta:   comimos el arroz que estaba excesivamente sabroso
#
# La palabra error era "ardoz" la cual tiene frecuencia 1 en el corpus, mientras que "arroz" tiene frecuencia 19, por lo que es mas problable y la corrige bien,
# sin embargo, una palabra que estaba bien como "sabroso" la corrige porque tiene frecuencia 1 en el corpus, y el min_freq = 3, ademas su distancia es de 1.5 por lo que acaba
# eligiendo esa otra palabra.
#
# A pesar de que elija mal esa palabra, el resultado de un hiper parametro de min_freq=3 es determinante para mejorar significativamente los resultados no solo obtenidos por la distancia.

# %% [markdown]
# **Conclusion**
#
# Las 2 mejoras implementadas mejoran significativamente lo que seria un autocorrector base con intercambio implementado, la penalizacion de distancia funciona correctamente
# y junto con la frecuencia minima de palabras mejoran mucho la calidad de los resultados, tambien teniendo en cuenta que usamos Damerau- Levenshtein para tener en cuenta
# la penalizacion en exchange tambien, en el base solo se tiene en cuenta insertar, eliminar y remplazar.
#
# Incluso al probar el autocorrector base con una sola mejora como lo es la min_freq de las palabras no alcanza el 95% de accuracy del modelo con la mejora en cercania de distancias de teclado y con las frecuencia minima de palabras, concluimos entonces, que efectivamente para este conjunto de validacion el modelo de distancias y frecuencias es una mejora ante el
# corrector base.
